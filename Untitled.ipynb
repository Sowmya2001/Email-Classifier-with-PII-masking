# %%
# !pip install tensorflow --timeout=300
# !pip install tensorflow -i https://pypi.douban.com/simple
# Out:
#     Uninstalling grpcio-1.42.0:
#       Successfully uninstalled grpcio-1.42.0
# Successfully installed absl-py-2.2.2 astunparse-1.6.3 flatbuffers-25.2.10 gast-0.6.0 google-pasta-0.2.0 grpcio-1.71.0 h5py-3.13.0 keras-3.9.2 libclang-18.1.1 markdown-it-py-3.0.0 mdurl-0.1.2 ml-dtypes-0.5.1 namex-0.0.8 numpy-2.0.2 opt-einsum-3.4.0 optree-0.15.0 protobuf-5.29.4 pygments-2.19.1 rich-14.0.0 tensorboard-2.19.0 tensorboard-data-server-0.7.2 tensorflow-2.19.0 tensorflow-io-gcs-filesystem-0.31.0 termcolor-3.0.1
# Looking in indexes: https://pypi.douban.com/simple
# Requirement already satisfied: tensorflow in c:\users\asus\anaconda3\lib\site-packages (2.19.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in c:\users\asus\anaconda3\lib\site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: tensorboard~=2.19.0 in c:\users\asus\anaconda3\lib\site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\asus\anaconda3\lib\site-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\asus\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\asus\anaconda3\lib\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\asus\anaconda3\lib\site-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\asus\anaconda3\lib\site-packages (from tensorflow) (4.13.2)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\asus\anaconda3\lib\site-packages (from tensorflow) (3.0.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\asus\anaconda3\lib\site-packages (from tensorflow) (0.31.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\asus\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\asus\anaconda3\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: setuptools in c:\users\asus\anaconda3\lib\site-packages (from tensorflow) (61.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\asus\anaconda3\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\asus\anaconda3\lib\site-packages (from tensorflow) (2.2.2)
# Requirement already satisfied: keras>=3.5.0 in c:\users\asus\anaconda3\lib\site-packages (from tensorflow) (3.9.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\asus\anaconda3\lib\site-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\asus\anaconda3\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: packaging in c:\users\asus\anaconda3\lib\site-packages (from tensorflow) (21.3)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in c:\users\asus\anaconda3\lib\site-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\asus\anaconda3\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\asus\anaconda3\lib\site-packages (from tensorflow) (2.27.1)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\asus\anaconda3\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\asus\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: rich in c:\users\asus\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (14.0.0)
# Requirement already satisfied: namex in c:\users\asus\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\asus\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (0.15.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\asus\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\asus\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.3)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\asus\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (2.0.3)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\asus\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.3.4)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\asus\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\asus\anaconda3\lib\site-packages (from packaging->tensorflow) (3.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\asus\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\asus\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\asus\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)

# %%
# !pip install -r requirements.txt --default-timeout=100
# Out:
# ^C

# %%
# !pip install -r requirements.txt --no-deps --default-timeout=100
# Out:
# Requirement already satisfied: fastapi in c:\users\asus\anaconda3\lib\site-packages (from -r requirements.txt (line 1)) (0.115.12)
# Collecting uvicorn
#   Using cached uvicorn-0.34.2-py3-none-any.whl (62 kB)
# Requirement already satisfied: pydantic in c:\users\asus\anaconda3\lib\site-packages (from -r requirements.txt (line 3)) (2.11.3)
# Collecting spacy
#   Using cached spacy-3.8.5-cp39-cp39-win_amd64.whl (12.3 MB)
# Requirement already satisfied: scikit-learn in c:\users\asus\anaconda3\lib\site-packages (from -r requirements.txt (line 5)) (1.0.2)
# Requirement already satisfied: torch in c:\users\asus\anaconda3\lib\site-packages (from -r requirements.txt (line 6)) (2.2.1)
# Collecting transformers
#   Using cached transformers-4.51.3-py3-none-any.whl (10.4 MB)
# Requirement already satisfied: pandas in c:\users\asus\anaconda3\lib\site-packages (from -r requirements.txt (line 8)) (1.4.2)
# Requirement already satisfied: numpy in c:\users\asus\anaconda3\lib\site-packages (from -r requirements.txt (line 9)) (2.0.2)
# Requirement already satisfied: tensorflow in c:\users\asus\anaconda3\lib\site-packages (from -r requirements.txt (line 11)) (2.19.0)
# Installing collected packages: uvicorn, transformers, spacy
# Successfully installed spacy-3.8.5 transformers-4.51.3 uvicorn-0.34.2

# %%
import uvicorn

# Run the FastAPI app
uvicorn.run("app:app", host="127.0.0.1", port=8000, reload=True)
# Out:
# INFO:     Will watch for changes in these directories: ['C:\\Users\\Asus\\Desktop\\Project']
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [4648] using StatReload
# Requirement already satisfied: fastapi in c:\users\asus\anaconda3\lib\site-packages (from -r requirements.txt (line 1)) (0.115.12)
# Collecting uvicorn
#   Using cached uvicorn-0.34.2-py3-none-any.whl (62 kB)
# Requirement already satisfied: pydantic in c:\users\asus\anaconda3\lib\site-packages (from -r requirements.txt (line 3)) (2.11.3)
# Collecting spacy
#   Using cached spacy-3.8.5-cp39-cp39-win_amd64.whl (12.3 MB)
# Requirement already satisfied: scikit-learn in c:\users\asus\anaconda3\lib\site-packages (from -r requirements.txt (line 5)) (1.0.2)
# Requirement already satisfied: torch in c:\users\asus\anaconda3\lib\site-packages (from -r requirements.txt (line 6)) (2.2.1)
# Collecting transformers
#   Downloading transformers-4.51.3-py3-none-any.whl (10.4 MB)
# Requirement already satisfied: pandas in c:\users\asus\anaconda3\lib\site-packages (from -r requirements.txt (line 8)) (1.4.2)
# Requirement already satisfied: numpy in c:\users\asus\anaconda3\lib\site-packages (from -r requirements.txt (line 9)) (2.0.2)
# Requirement already satisfied: tensorflow in c:\users\asus\anaconda3\lib\site-packages (from -r requirements.txt (line 11)) (2.19.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\asus\anaconda3\lib\site-packages (from fastapi->-r requirements.txt (line 1)) (4.13.2)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in c:\users\asus\anaconda3\lib\site-packages (from fastapi->-r requirements.txt (line 1)) (0.46.2)
# Requirement already satisfied: click>=7.0 in c:\users\asus\anaconda3\lib\site-packages (from uvicorn->-r requirements.txt (line 2)) (8.0.4)
# Collecting h11>=0.8
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\asus\anaconda3\lib\site-packages (from pydantic->-r requirements.txt (line 3)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in c:\users\asus\anaconda3\lib\site-packages (from pydantic->-r requirements.txt (line 3)) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\asus\anaconda3\lib\site-packages (from pydantic->-r requirements.txt (line 3)) (0.4.0)
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.5.0-py3-none-any.whl (182 kB)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.12-cp39-cp39-win_amd64.whl (25 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\asus\anaconda3\lib\site-packages (from spacy->-r requirements.txt (line 4)) (4.64.0)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.9-cp39-cp39-win_amd64.whl (122 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\asus\anaconda3\lib\site-packages (from spacy->-r requirements.txt (line 4)) (21.3)
# Collecting srsly<3.0.0,>=2.4.3
#   Downloading srsly-2.5.1-cp39-cp39-win_amd64.whl (633 kB)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.11-cp39-cp39-win_amd64.whl (39 kB)
# Requirement already satisfied: jinja2 in c:\users\asus\anaconda3\lib\site-packages (from spacy->-r requirements.txt (line 4)) (2.11.3)
# Collecting typer<1.0.0,>=0.3.0
#   Downloading typer-0.15.2-py3-none-any.whl (45 kB)
# Collecting wasabi<1.2.0,>=0.9.1
#   Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\asus\anaconda3\lib\site-packages (from spacy->-r requirements.txt (line 4)) (2.27.1)
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Collecting weasel<0.5.0,>=0.1.0
#   Downloading weasel-0.4.1-py3-none-any.whl (50 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Requirement already satisfied: setuptools in c:\users\asus\anaconda3\lib\site-packages (from spacy->-r requirements.txt (line 4)) (61.2.0)
# Collecting thinc<8.4.0,>=8.3.4
#   Downloading thinc-8.3.6-cp39-cp39-win_amd64.whl (1.8 MB)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\asus\anaconda3\lib\site-packages (from scikit-learn->-r requirements.txt (line 5)) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\asus\anaconda3\lib\site-packages (from scikit-learn->-r requirements.txt (line 5)) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\asus\anaconda3\lib\site-packages (from scikit-learn->-r requirements.txt (line 5)) (1.1.0)
# Requirement already satisfied: fsspec in c:\users\asus\anaconda3\lib\site-packages (from torch->-r requirements.txt (line 6)) (2022.2.0)
# Requirement already satisfied: networkx in c:\users\asus\anaconda3\lib\site-packages (from torch->-r requirements.txt (line 6)) (2.7.1)
# Requirement already satisfied: sympy in c:\users\asus\anaconda3\lib\site-packages (from torch->-r requirements.txt (line 6)) (1.10.1)
# Requirement already satisfied: filelock in c:\users\asus\anaconda3\lib\site-packages (from torch->-r requirements.txt (line 6)) (3.6.0)
# Collecting tokenizers<0.22,>=0.21
#   Downloading tokenizers-0.21.1-cp39-abi3-win_amd64.whl (2.4 MB)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\asus\anaconda3\lib\site-packages (from transformers->-r requirements.txt (line 7)) (2022.3.15)
# Collecting huggingface-hub<1.0,>=0.30.0
#   Downloading huggingface_hub-0.30.2-py3-none-any.whl (481 kB)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\asus\anaconda3\lib\site-packages (from transformers->-r requirements.txt (line 7)) (6.0)
# Collecting safetensors>=0.4.3
#   Downloading safetensors-0.5.3-cp38-abi3-win_amd64.whl (308 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\asus\anaconda3\lib\site-packages (from pandas->-r requirements.txt (line 8)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asus\anaconda3\lib\site-packages (from pandas->-r requirements.txt (line 8)) (2021.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\asus\anaconda3\lib\site-packages (from tensorflow->-r requirements.txt (line 11)) (25.2.10)
# Requirement already satisfied: tensorboard~=2.19.0 in c:\users\asus\anaconda3\lib\site-packages (from tensorflow->-r requirements.txt (line 11)) (2.19.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\asus\anaconda3\lib\site-packages (from tensorflow->-r requirements.txt (line 11)) (3.0.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\asus\anaconda3\lib\site-packages (from tensorflow->-r requirements.txt (line 11)) (2.2.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\asus\anaconda3\lib\site-packages (from tensorflow->-r requirements.txt (line 11)) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\asus\anaconda3\lib\site-packages (from tensorflow->-r requirements.txt (line 11)) (1.71.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in c:\users\asus\anaconda3\lib\site-packages (from tensorflow->-r requirements.txt (line 11)) (0.5.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\asus\anaconda3\lib\site-packages (from tensorflow->-r requirements.txt (line 11)) (1.6.3)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\asus\anaconda3\lib\site-packages (from tensorflow->-r requirements.txt (line 11)) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\asus\anaconda3\lib\site-packages (from tensorflow->-r requirements.txt (line 11)) (0.2.0)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\asus\anaconda3\lib\site-packages (from tensorflow->-r requirements.txt (line 11)) (3.13.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\asus\anaconda3\lib\site-packages (from tensorflow->-r requirements.txt (line 11)) (3.4.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\asus\anaconda3\lib\site-packages (from tensorflow->-r requirements.txt (line 11)) (0.31.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\asus\anaconda3\lib\site-packages (from tensorflow->-r requirements.txt (line 11)) (18.1.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\asus\anaconda3\lib\site-packages (from tensorflow->-r requirements.txt (line 11)) (1.12.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\asus\anaconda3\lib\site-packages (from tensorflow->-r requirements.txt (line 11)) (5.29.4)
# Requirement already satisfied: keras>=3.5.0 in c:\users\asus\anaconda3\lib\site-packages (from tensorflow->-r requirements.txt (line 11)) (3.9.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\asus\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow->-r requirements.txt (line 11)) (0.37.1)
# Requirement already satisfied: colorama in c:\users\asus\anaconda3\lib\site-packages (from click>=7.0->uvicorn->-r requirements.txt (line 2)) (0.4.4)
# Collecting fsspec
#   Downloading fsspec-2025.3.2-py3-none-any.whl (194 kB)
# Requirement already satisfied: rich in c:\users\asus\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow->-r requirements.txt (line 11)) (14.0.0)
# Requirement already satisfied: optree in c:\users\asus\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow->-r requirements.txt (line 11)) (0.15.0)
# Requirement already satisfied: namex in c:\users\asus\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow->-r requirements.txt (line 11)) (0.0.8)
# Collecting language-data>=1.2
#   Downloading language_data-1.3.0-py3-none-any.whl (5.4 MB)
# Collecting marisa-trie>=1.1.0
#   Downloading marisa_trie-1.2.1-cp39-cp39-win_amd64.whl (152 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\asus\anaconda3\lib\site-packages (from packaging>=20.0->spacy->-r requirements.txt (line 4)) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy->-r requirements.txt (line 4)) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy->-r requirements.txt (line 4)) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\asus\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy->-r requirements.txt (line 4)) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\asus\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy->-r requirements.txt (line 4)) (2.0.4)
# Collecting scipy>=1.1.0
#   Downloading scipy-1.13.1-cp39-cp39-win_amd64.whl (46.2 MB)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\asus\anaconda3\lib\site-packages (from starlette<0.47.0,>=0.40.0->fastapi->-r requirements.txt (line 1)) (4.9.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\asus\anaconda3\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi->-r requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\asus\anaconda3\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi->-r requirements.txt (line 1)) (1.2.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\asus\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow->-r requirements.txt (line 11)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\asus\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow->-r requirements.txt (line 11)) (2.0.3)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\asus\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow->-r requirements.txt (line 11)) (3.3.4)
# Collecting blis<1.4.0,>=1.3.0
#   Downloading blis-1.3.0.tar.gz (2.5 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
# Collecting thinc<8.4.0,>=8.3.4
#   Downloading thinc-8.3.4-cp39-cp39-win_amd64.whl (1.5 MB)
# Collecting blis<1.3.0,>=1.2.0
#   Downloading blis-1.2.1.tar.gz (2.5 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting confection<1.0.0,>=0.0.1
#   Downloading confection-0.1.5-py3-none-any.whl (35 kB)
# Collecting shellingham>=1.3.0
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\asus\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow->-r requirements.txt (line 11)) (2.19.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\asus\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow->-r requirements.txt (line 11)) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\asus\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow->-r requirements.txt (line 11)) (0.1.2)
# Collecting colorama
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting smart-open<8.0.0,>=5.2.1
#   Downloading smart_open-7.1.0-py3-none-any.whl (61 kB)
# Collecting cloudpathlib<1.0.0,>=0.7.0
#   Downloading cloudpathlib-0.21.0-py3-none-any.whl (52 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\asus\anaconda3\lib\site-packages (from jinja2->spacy->-r requirements.txt (line 4)) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\asus\anaconda3\lib\site-packages (from sympy->torch->-r requirements.txt (line 6)) (1.2.1)
# Building wheels for collected packages: blis
#   Building wheel for blis (PEP 517): started
#   Building wheel for blis (PEP 517): finished with status 'error'
# Failed to build blis
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\Asus\anaconda3\python.exe' 'C:\Users\Asus\AppData\Local\Temp\pip-standalone-pip-wspmrlvy\__env_pip__.zip\pip' install --ignore-installed --no-user --prefix 'C:\Users\Asus\AppData\Local\Temp\pip-build-env-y7qn_kl3\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools 'cython>=3.0,<4.0' 'numpy>=1.19.3,<3.0.0'
#        cwd: None
#   Complete output (2 lines):
#   ERROR: Could not find a version that satisfies the requirement setuptools (from versions: none)
#   ERROR: No matching distribution found for setuptools
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/96/f3/7c5a47a0d5ec0362bab29fd4f497b4b1975473bf30b7a02bc9c0b0e84f7a/blis-1.3.0.tar.gz#sha256=1695a87e3fc4c20d9b9140f5238cac0514c411b750e8cdcec5d8320c71f62e99 (from https://pypi.org/simple/blis/) (requires-python:<3.14,>=3.6). Command errored out with exit status 1: 'C:\Users\Asus\anaconda3\python.exe' 'C:\Users\Asus\AppData\Local\Temp\pip-standalone-pip-wspmrlvy\__env_pip__.zip\pip' install --ignore-installed --no-user --prefix 'C:\Users\Asus\AppData\Local\Temp\pip-build-env-y7qn_kl3\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools 'cython>=3.0,<4.0' 'numpy>=1.19.3,<3.0.0' Check the logs for full command output.
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\Asus\anaconda3\python.exe' 'C:\Users\Asus\anaconda3\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' build_wheel 'C:\Users\Asus\AppData\Local\Temp\tmp6j0e8n7e'
#        cwd: C:\Users\Asus\AppData\Local\Temp\pip-install-63yildiu\blis_8a870458057540958e684d636d2441b0
#   Complete output (32 lines):
#   BLIS_COMPILER? None
#   C:\Users\Asus\AppData\Local\Temp\pip-build-env-1mbzwunm\overlay\Lib\site-packages\setuptools\dist.py:759: SetuptoolsDeprecationWarning: License classifiers are deprecated.
#   !!
#
#           ********************************************************************************
#           Please consider removing the following classifiers in favor of a SPDX license expression:
#
#           License :: OSI Approved :: BSD License
#
#           See https://packaging.python.org/en/latest/guides/writing-pyproject-toml/#license for details.
#           ********************************************************************************
#
#   !!
#     self._finalize_license_expression()
#   running bdist_wheel
#   running build
#   running build_py
#   creating build\lib.win-amd64-cpython-39\blis
#   copying blis\about.py -> build\lib.win-amd64-cpython-39\blis
#   copying blis\benchmark.py -> build\lib.win-amd64-cpython-39\blis
#   copying blis\__init__.py -> build\lib.win-amd64-cpython-39\blis
#   creating build\lib.win-amd64-cpython-39\blis\tests
#   copying blis\tests\common.py -> build\lib.win-amd64-cpython-39\blis\tests
#   copying blis\tests\test_dotv.py -> build\lib.win-amd64-cpython-39\blis\tests
#   copying blis\tests\test_gemm.py -> build\lib.win-amd64-cpython-39\blis\tests
#   copying blis\tests\__init__.py -> build\lib.win-amd64-cpython-39\blis\tests
#   copying blis\cy.pyx -> build\lib.win-amd64-cpython-39\blis
#   copying blis\py.pyx -> build\lib.win-amd64-cpython-39\blis
#   copying blis\cy.pxd -> build\lib.win-amd64-cpython-39\blis
#   copying blis\__init__.pxd -> build\lib.win-amd64-cpython-39\blis
#   running build_ext
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   ----------------------------------------
#   ERROR: Failed building wheel for blis
# ERROR: Could not build wheels for blis which use PEP 517 and cannot be installed directly
# WARNING:  StatReload detected changes in 'app.py'. Reloading...
